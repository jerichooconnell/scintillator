# %%
from topas2numpy import read_ntuple
y = read_ntuple('PhotodiodeSurface.phsp')

# %%
# %cat PhotodiodeSurface.header
# Out:
# Number of Original Histories: 10000000
# Number of Scored Entries: 12891650
# Number of Bytes per Particle: 24
#
# Byte order of each record is as follows:
# f4: Local position X [cm]
# f4: Local position Y [cm]
# f4: Local position Z [cm]
# f4: Wavelength [nm]
# f4: Arrival time [ns]
# i4: ProcessID: 1 Scintillation, 2 Cerenkov, 3 Absorption

# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
xx = [y[kk][0] for kk in range(y.size)]
yy = [y[kk][1] for kk in range(y.size)]

# %%
from matplotlib.image import NonUniformImage
from pylab import figure, cm
from matplotlib.colors import LogNorm

plt.figure()

xedges = np.linspace(-20.0704,20.0704,1024)
yedges = np.linspace(-15.0528,15.0528,769)

# H, xedges, yedges = np.histogram2d(xx, yy, bins=500)
plt.hist2d(xx,yy, bins = [xedges,yedges], cmap=cm.jet, norm=LogNorm())
axis('image')
plt.xlabel('X [cm]')
plt.ylabel('Y [cm]')
cbar = plt.colorbar()
cbar.set_label('Counts')
# Out:
# <img src="data:image/png;base64,..." width="640">
