# %%
from topas2numpy import read_ntuple
y = read_ntuple('keepers/PhotodiodeSurface.phsp')

# %%
# %cat PhotodiodeSurface.header
# Out:
# cat: PhotodiodeSurface.header: No such file or directory

# %%
# !ls -l -hs keepers/
# Out:
# total 4.0K
# 4.0K -rw-rw-r-- 1 xcite xcite 318 Jun  1 09:45 PhotodiodeSurface.header
#    0 -rw-rw-r-- 1 xcite xcite   0 Jun  1 09:45 PhotodiodeSurface.phsp

# %%
xx = [y[kk][0] for kk in range(y.size)]
yy = [y[kk][1] for kk in range(y.size)]

# %%
from matplotlib.image import NonUniformImage
from pylab import figure, cm
from matplotlib.colors import LogNorm

plt.figure()

xedges = np.linspace(-20.0704,20.0704,1024)
yedges = np.linspace(-15.0528,15.0528,769)

# H, xedges, yedges = np.histogram2d(xx, yy, bins=500)
plt.hist2d(xx,yy, bins = [xedges,yedges], cmap=cm.jet, norm=LogNorm())
axis('image')
plt.xlabel('X [mm]')
plt.ylabel('Y [mm]')
cbar = plt.colorbar()
cbar.set_label('Counts')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/xcite/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app
# /home/xcite/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   from ipykernel import kernelapp as app

# %%
fig = plt.figure(figsize=(7, 3))
ax = fig.add_subplot(111, title='pcolormesh: actual edges',aspect='equal')

xedges = np.linspace(0,401.408,1025)

yedges = np.linspace(0,301.056,769)

H, xedges, yedges = np.histogram2d(xx, yy, bins=(xedges, yedges))

H = H.T 

im = NonUniformImage(ax, interpolation='bilinear')

xcenters = (xedges[:-1] + xedges[1:]) / 2

ycenters = (yedges[:-1] + yedges[1:]) / 2

im.set_data(xcenters, ycenters, H)

ax.images.append(im)

plt.show()

X, Y = np.meshgrid(xedges, yedges)

plt.pcolormesh(X, Y, H)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
xcenters
# Out:
# array([1.96000e-01, 5.88000e-01, 9.80000e-01, ..., 4.00428e+02,
#        4.00820e+02, 4.01212e+02])

# %%
xcenters.shape
# Out:
# (1024,)

# %%
ycenters.shape
# Out:
# (768,)

# %%
X
# Out:
# array([[0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02],
#        [0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02],
#        [0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02],
#        ...,
#        [0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02],
#        [0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02],
#        [0.00000e+00, 3.92000e-01, 7.84000e-01, ..., 4.00624e+02,
#         4.01016e+02, 4.01408e+02]])
