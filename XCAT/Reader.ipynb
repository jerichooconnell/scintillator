# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import io

# %%
from numpy import genfromtxt
my_data = genfromtxt('phantomDose_test120kVp_32.csv', delimiter=',')

# %%
print(my_data)
# Out:
# [[  0.           0.           0.         269.2442627 ]
#  [  0.           1.           0.         303.31762695]
#  [  0.           2.           0.         307.31790161]
#  ...
#  [ 49.          47.           0.          41.80237198]
#  [ 49.          48.           0.          38.22290421]
#  [ 49.          49.           0.          31.50589752]]

# %%
plt.figure()
plt.imshow(my_data[:,3].reshape(50,50,order ='f'))
# Out:
# <img src="data:image/png;base64,..." width="640">
