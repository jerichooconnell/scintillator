# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import topas2numpy

# %%
# !rename -e 's/\d+/sprintf("%03d",$&)/e' -- ../batch_submission_smaller/*.csv

# %%
import glob

files = sorted(glob.glob('../batch_submission_smaller/*.csv'))

# %%
files
# Out:
# ['../batch_submission_smaller/Readout_000.csv',
#  '../batch_submission_smaller/Readout_002.csv',
#  '../batch_submission_smaller/Readout_004.csv',
#  '../batch_submission_smaller/Readout_006.csv',
#  '../batch_submission_smaller/Readout_008.csv',
#  '../batch_submission_smaller/Readout_010.csv',
#  '../batch_submission_smaller/Readout_012.csv',
#  '../batch_submission_smaller/Readout_014.csv',
#  '../batch_submission_smaller/Readout_016.csv',
#  '../batch_submission_smaller/Readout_018.csv',
#  '../batch_submission_smaller/Readout_020.csv',
#  '../batch_submission_smaller/Readout_022.csv',
#  '../batch_submission_smaller/Readout_024.csv',
#  '../batch_submission_smaller/Readout_026.csv',
#  '../batch_submission_smaller/Readout_028.csv',
#  '../batch_submission_smaller/Readout_030.csv',
#  '../batch_submission_smaller/Readout_032.csv',
#  '../batch_submission_smaller/Readout_034.csv',
#  '../batch_submission_smaller/Readout_036.csv',
#  '../batch_submission_smaller/Readout_038.csv',
# ...

# %%
flood = topas2numpy.BinnedResult('Readout_flood.csv').data['Sum'].squeeze().T

# %%
import scipy

# %%
flood_128 = np.zeros([128,512])

xf = np.linspace(0,128,128)
x = np.linspace(0,128,124)
for ii in range(512):
    
    flood_128[:,ii] = np.interp(xf,x,flood[:,ii])

# %%
images = np.zeros([180,128,512])

for ii, file in enumerate(files):
    
    images[ii] = -np.log(topas2numpy.BinnedResult(file).data['Sum'].squeeze().T/flood_128)

# %%
import tigre

# %%
angles = np.linspace(0,358,180)*np.pi/180

# %%
angles
# Out:
# array([0.        , 0.03490659, 0.06981317, 0.10471976, 0.13962634,
#        0.17453293, 0.20943951, 0.2443461 , 0.27925268, 0.31415927,
#        0.34906585, 0.38397244, 0.41887902, 0.45378561, 0.48869219,
#        0.52359878, 0.55850536, 0.59341195, 0.62831853, 0.66322512,
#        0.6981317 , 0.73303829, 0.76794487, 0.80285146, 0.83775804,
#        0.87266463, 0.90757121, 0.9424778 , 0.97738438, 1.01229097,
#        1.04719755, 1.08210414, 1.11701072, 1.15191731, 1.18682389,
#        1.22173048, 1.25663706, 1.29154365, 1.32645023, 1.36135682,
#        1.3962634 , 1.43116999, 1.46607657, 1.50098316, 1.53588974,
#        1.57079633, 1.60570291, 1.6406095 , 1.67551608, 1.71042267,
#        1.74532925, 1.78023584, 1.81514242, 1.85004901, 1.88495559,
#        1.91986218, 1.95476876, 1.98967535, 2.02458193, 2.05948852,
#        2.0943951 , 2.12930169, 2.16420827, 2.19911486, 2.23402144,
#        2.26892803, 2.30383461, 2.3387412 , 2.37364778, 2.40855437,
# ...

# %%
geomet = tigre.geometry_default(high_quality=True,nVoxel = [64,512,512])
geomet.nDetector = np.array([128,512])
geomet.dDetector = np.array([0.784, 0.784])

# I think I can get away with this
geomet.sDetector = geomet.dDetector * geomet.nDetector    

geomet.sVoxel = np.array((160, 160, 160)) 
geomet.dVoxel = geomet.sVoxel/geomet.nVoxel

# %%
phantom = np.load('/home/xcite/xpecgen/xpecgen/data/phantoms/catphan_low_contrast_512.npy')

# %%
images.shape
# Out:
# (180, 128, 512)

# %%
im = tigre.algorithms.FDK(20*images[:,:,:],geomet,angles)
# Out:
# ---------------------------------------------------------------------------
# TigreCudaCallError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3330                 else:
# -> 3331                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3332             finally:
#
# <ipython-input-271-e556f9d1e342> in <module>
# ----> 1 im = tigre.algorithms.FDK(20*images[:,:,:],geomet,angles)
#
# ~/.local/lib/python3.7/site-packages/pytigre-0.1.8-py3.7-linux-x86_64.egg/tigre/algorithms/single_pass_algorithms.py in FDK(proj, geo, angles, **kwargs)
#     118     # scipy.io.savemat('Tests/Filter_data', m)
# --> 119     res = Atb(proj_filt, geo, geo.angles, 'FDK')
#     120     # res = 0
#
# ~/.local/lib/python3.7/site-packages/pytigre-0.1.8-py3.7-linux-x86_64.egg/tigre/utilities/Atb.py in Atb(projections, geo, angles, krylov)
#      23
# ...

# %%
im2 = tigre.algorithms.FDK(20*np.tile(np.mean(images[:,:,:],1),[128,1,1]).transpose([1,0,2]),geomet,angles)

# %%
class IndexTracker(object):
    def __init__(self, ax, X):
        self.ax = ax
        ax.set_title('Geometry Viewer')

        self.X = X
        rows, cols, self.slices = X.shape
        self.ind = self.slices//2

        self.im = ax.imshow(self.X[:, :, self.ind])
        self.update()

    def onscroll(self, event):
        #print("%s %s" % (event.button, event.step))
        if event.button == 'up':
            self.ind = (self.ind + 1) % self.slices
        else:
            self.ind = (self.ind - 1) % self.slices
        self.update()

    def update(self):
        self.im.set_data(self.X[:, :, self.ind])
        self.ax.set_ylabel('slice %s' % self.ind)
        self.im.axes.figure.canvas.draw()

# %%
fig, ax = plt.subplots(1, 1)

tracker = IndexTracker(ax, im2.T)

fig.canvas.mpl_connect('scroll_event', tracker.onscroll)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
fig, ax = plt.subplots(1, 1)

tracker = IndexTracker(ax, np.tile(np.mean(images[:,:,:],1),[128,1,1]).transpose([1,0,2]).transpose([0,2,1]))

fig.canvas.mpl_connect('scroll_event', tracker.onscroll)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
plt.figure()
plt.imshow(flood_128 - topas2numpy.BinnedResult(file).data['Sum'].squeeze().T)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
