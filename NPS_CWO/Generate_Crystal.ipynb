# %% [markdown]
# # File for writing a textfile that creates the crystal

# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n = 0
outF = open("Crystal_Ge.txt", "w")
for xx in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):
    for yy in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):
        
        # write line to output file
        outF.write(f's:Ge/CWO_{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/CWO_{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/CWO_{n}/HLX = 0.379 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLY = 0.379 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/CWO_{n}/Material = "CWO"\n')
        outF.write(f'd:Ge/CWO_{n}/TransX = {xx} mm\n'),
        outF.write(f'd:Ge/CWO_{n}/TransY = {yy} mm\n\n')
        
        # write line to output file
        outF.write(f's:Ge/Septa_{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/Septa_{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/Septa_{n}/HLX = 0.013 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/HLY = 0.379 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/Septa_{n}/Material = "Al_Mylar"\n')
        outF.write(f'd:Ge/Septa_{n}/TransX = Ge/CWO_{n}/TransX - .392 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/TransY = {yy} mm\n\n')
        
        # write line to output file
        outF.write(f's:Ge/Septa_top{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/Septa_top{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLX = 0.392 mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLY = 0.013 mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/Septa_top{n}/Material = "Al_Mylar"\n')
        outF.write(f'd:Ge/Septa_top{n}/TransY = Ge/CWO_{n}/TransY - .392 mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/TransX = {xx} mm\n\n')
        
        if yy == 9.408:
            
             # write line to output file
            outF.write(f's:Ge/Septa_bottom{n}/Parent   = "SeptaGroup"\n'),
            outF.write(f's:Ge/Septa_bottom{n}/Type = "TsBox"\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLX = 0.392 mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLY = 0.013 mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLZ = 7.5 mm\n'),
            outF.write(f's:Ge/Septa_bottom{n}/Material = "Al_Mylar"\n')
            outF.write(f'd:Ge/Septa_bottom{n}/TransY = Ge/CWO_{n}/TransY + .392 mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/TransX = {xx} mm\n\n')
        
        if xx == 9.408:
        
            # write line to output file
            outF.write(f's:Ge/Septa_left{n}/Parent   = "SeptaGroup"\n'),
            outF.write(f's:Ge/Septa_left{n}/Type = "TsBox"\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLX = 0.013 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLY = 0.379 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLZ = 7.5 mm\n'),
            outF.write(f's:Ge/Septa_left{n}/Material = "Al_Mylar"\n')
            outF.write(f'd:Ge/Septa_left{n}/TransX = Ge/CWO_{n}/TransX + .392 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/TransY = {yy} mm\n\n')
      
        
        n+=1
        
#         if n == 20:
            
#             break
            
#     if n == 20:
            
#             break
        
outF.close()

# %%
plt.figure()
n = 0
for xx in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):
    for yy in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):
        
        plt.plot(xx,yy,'b*')
        
        plt.plot(xx,yy - .392,'r*')

        
        plt.plot(xx - .392,yy,'r*')
        
        if n == 312-25:
            
            plt.plot(xx,yy,'y*')
        
        if yy == 9.408:
            plt.plot(xx,yy + .392,'r*')
        
        if xx == 9.408:

        
            plt.plot(xx + .392,yy,'r*')
      
        
        n+=1
        
#         if n == 20:
            
#             break
            
#     if n == 20:
            
#             break
        
# outF.close()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
11*11/2
# Out:
# 60.5

# %%
mm = 0
outF = open("Sc_COW.txt", "w")
for xx in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):
    for yy in np.round(np.linspace(-9.8+.392,9.8-.392,25),decimals=5):

        outF.write(f's:Sc/EnergyDeposition_{mm}/Component                 = "CWO_{mm}"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/Quantity                  = "EnergyDeposit"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/OutputType                = "csv"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/IfOutputFileAlreadyExists = "Overwrite"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/OutputFile = "runs/EnergyDeposit_{mm}"\n\n'),
        
        mm += 1

outF.close()

# %%
n = 0
outF = open("Sc_COW_small.txt", "w")
for nn in range(60 - 22 - 2,60 + 22 + 2,25):
    for mm in range(nn,nn+5):

        outF.write(f's:Sc/EnergyDeposition_{mm}/Component                 = "CWO_{mm}"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/Quantity                  = "EnergyDeposit"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/OutputType                = "csv"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/IfOutputFileAlreadyExists = "Overwrite"\n'),
        outF.write(f's:Sc/EnergyDeposition_{mm}/OutputFile = "runs/EnergyDeposit_{mm}"\n\n'),

outF.close()

# %%
n = 0
outF = open("myOutFile.txt", "w")
for xx in np.linspace(-25.039,25.039,48):
    for yy in np.linspace(-25.039,25.039,48):
        
        # write line to output file
        outF.write(f's:Ge/CWO_{n}/Parent   = "Septa"\n'),
        outF.write(f'b:Ge/CWO_{n}/IsParallel = "True"\n'),
        outF.write(f's:Ge/CWO_{n}/Type = "TsBox"\n'),
        outF.write(f's:Ge/CWO_{n}/ParallelWorldName = "Crystals"\n'),
        outF.write(f'd:Ge/CWO_{n}/HLX = 0.3925 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLY = 0.3925 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/CWO_{n}/Material = "CWO"\n')
        outF.write(f'd:Ge/CWO_{n}/TransX = {xx} mm\n'),
        outF.write(f'd:Ge/CWO_{n}/TransY = {yy} mm\n\n')
        
        
        n+=1
    
outF.close()

# %%
n = 0
outF = open("myOutFile_Small.txt", "w")
for xx in np.linspace(-20.0,20.0,11):
    for yy in np.linspace(-20.0,20.0,11):
        
        # write line to output file
        outF.write(f's:Ge/CWO_{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/CWO_{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/CWO_{n}/HLX = 1.570 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLY = 1.570 mm\n'),
        outF.write(f'd:Ge/CWO_{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/CWO_{n}/Material = "CWO"\n')
        outF.write(f'd:Ge/CWO_{n}/TransX = {xx} mm\n'),
        outF.write(f'd:Ge/CWO_{n}/TransY = {yy} mm\n\n')
        
        # write line to output file
        outF.write(f's:Ge/Septa_{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/Septa_{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/Septa_{n}/HLX = 0.430 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/HLY = 1.570 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/Septa_{n}/Material = "Al_Mylar"\n')
        outF.write(f'd:Ge/Septa_{n}/TransX = Ge/CWO_{n}/TransX - 2 mm\n'),
        outF.write(f'd:Ge/Septa_{n}/TransY = {yy} mm\n\n')
        
        # write line to output file
        outF.write(f's:Ge/Septa_top{n}/Parent   = "SeptaGroup"\n'),
        outF.write(f's:Ge/Septa_top{n}/Type = "TsBox"\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLX = 2. mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLY = 0.430 mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/HLZ = 7.5 mm\n'),
        outF.write(f's:Ge/Septa_top{n}/Material = "Al_Mylar"\n')
        outF.write(f'd:Ge/Septa_top{n}/TransY = Ge/CWO_{n}/TransY - 2 mm\n'),
        outF.write(f'd:Ge/Septa_top{n}/TransX = {xx} mm\n\n')
        
        if yy == 20.:
            
             # write line to output file
            outF.write(f's:Ge/Septa_bottom{n}/Parent   = "SeptaGroup"\n'),
            outF.write(f's:Ge/Septa_bottom{n}/Type = "TsBox"\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLX = 2. mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLY = 0.430 mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/HLZ = 7.5 mm\n'),
            outF.write(f's:Ge/Septa_bottom{n}/Material = "Al_Mylar"\n')
            outF.write(f'd:Ge/Septa_bottom{n}/TransY = Ge/CWO_{n}/TransY + 2 mm\n'),
            outF.write(f'd:Ge/Septa_bottom{n}/TransX = {xx} mm\n\n')
        
        if xx == 20.:
        
            # write line to output file
            outF.write(f's:Ge/Septa_left{n}/Parent   = "SeptaGroup"\n'),
            outF.write(f's:Ge/Septa_left{n}/Type = "TsBox"\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLX = 0.430 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLY = 1.570 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/HLZ = 7.5 mm\n'),
            outF.write(f's:Ge/Septa_left{n}/Material = "Al_Mylar"\n')
            outF.write(f'd:Ge/Septa_left{n}/TransX = Ge/CWO_{n}/TransX + 2 mm\n'),
            outF.write(f'd:Ge/Septa_left{n}/TransY = {yy} mm\n\n')
      
        
        n+=1
    
outF.close()

# %%
1.570*2 - 4
# Out:
# -0.8599999999999999

# %%
# %cat myOutFile_Small.txt
# Out:
# s:Ge/CWO_0/Parent   = "Septa"
# b:Ge/CWO_0/IsParallel = "True"
# s:Ge/CWO_0/Type = "TsBox"
# s:Ge/CWO_0/ParallelWorldName = "Crystals"
# d:Ge/CWO_0/HLX = 0.785 mm
# d:Ge/CWO_0/HLY = 0.785 mm
# d:Ge/CWO_0/HLZ = 7.5 mm
# s:Ge/CWO_0/Material = "CWO"
# d:Ge/CWO_0/TransX = -25.039 mm
# d:Ge/CWO_0/TransY = -25.039 mm
#
# s:Ge/CWO_1/Parent   = "Septa"
# b:Ge/CWO_1/IsParallel = "True"
# s:Ge/CWO_1/Type = "TsBox"
# s:Ge/CWO_1/ParallelWorldName = "Crystals"
# d:Ge/CWO_1/HLX = 0.785 mm
# d:Ge/CWO_1/HLY = 0.785 mm
# d:Ge/CWO_1/HLZ = 7.5 mm
# s:Ge/CWO_1/Material = "CWO"
# d:Ge/CWO_1/TransX = -25.039 mm
# d:Ge/CWO_1/TransY = -20.486454545454546 mm
#
# s:Ge/CWO_2/Parent   = "Septa"
# b:Ge/CWO_2/IsParallel = "True"
# s:Ge/CWO_2/Type = "TsBox"
# s:Ge/CWO_2/ParallelWorldName = "Crystals"
# d:Ge/CWO_2/HLX = 0.785 mm
# d:Ge/CWO_2/HLY = 0.785 mm
# d:Ge/CWO_2/HLZ = 7.5 mm
# s:Ge/CWO_2/Material = "CWO"
# d:Ge/CWO_2/TransX = -25.039 mm
# d:Ge/CWO_2/TransY = -15.933909090909092 mm
#
# ...

# %%
50.078/2
# Out:
# 25.039

# %%
96/2
# Out:
# 48.0

# %%
192*0.784 - 0.392
# Out:
# 150.13600000000002

# %%
np.linspace(-200.312,200.312,512)
# Out:
# array([-200.312, -199.528, -198.744, -197.96 , -197.176, -196.392,
#        -195.608, -194.824, -194.04 , -193.256, -192.472, -191.688,
#        -190.904, -190.12 , -189.336, -188.552, -187.768, -186.984,
#        -186.2  , -185.416, -184.632, -183.848, -183.064, -182.28 ,
#        -181.496, -180.712, -179.928, -179.144, -178.36 , -177.576,
#        -176.792, -176.008, -175.224, -174.44 , -173.656, -172.872,
#        -172.088, -171.304, -170.52 , -169.736, -168.952, -168.168,
#        -167.384, -166.6  , -165.816, -165.032, -164.248, -163.464,
#        -162.68 , -161.896, -161.112, -160.328, -159.544, -158.76 ,
#        -157.976, -157.192, -156.408, -155.624, -154.84 , -154.056,
#        -153.272, -152.488, -151.704, -150.92 , -150.136, -149.352,
#        -148.568, -147.784, -147.   , -146.216, -145.432, -144.648,
#        -143.864, -143.08 , -142.296, -141.512, -140.728, -139.944,
#        -139.16 , -138.376, -137.592, -136.808, -136.024, -135.24 ,
# ...

# %%
200.312 -199.528
# Out:
# 0.7840000000000202
