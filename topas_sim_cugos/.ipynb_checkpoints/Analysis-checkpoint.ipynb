# %%
# %pylab nbagg

import topas2numpy
import tigre

# !rename -e 's/\d+/sprintf("%03d",$&)/e' -- ../batch_submission_W/*.csv

import glob

files = sorted(glob.glob('../batch_submission_W/*.csv'))

flood = topas2numpy.BinnedResult('Readout_flood_W.csv').data['Sum'].squeeze().T

plt.figure()
plt.plot(np.mean(flood,0))

plt.plot(np.convolve(np.mean(flood,0),10*[0.1],mode='same'))
plt.plot(np.convolve(np.mean(flood,0),20*[0.05],mode='same'))
plt.plot(np.convolve(np.mean(flood,0),40*[0.025],mode='same'))

new_flood = np.convolve(np.mean(flood,0),40*[0.025],mode='same')

new_flood[:106] = np.convolve(np.mean(flood,0),10*[0.1],mode='same')[:106]
new_flood[415:] = np.convolve(np.mean(flood,0),10*[0.1],mode='same')[415:]

plt.figure()
plt.imshow(np.tile(new_flood,[128,1]))
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
images = np.zeros([180,128,512])

for ii, file in enumerate(files):
    
    print(file)
    
    images[ii] = -np.log(topas2numpy.BinnedResult(file).data['Sum'].squeeze().T/new_flood)
# Out:
# ../batch_submission_W/Readout_000.csv
# ../batch_submission_W/Readout_002.csv
# ../batch_submission_W/Readout_004.csv
# ../batch_submission_W/Readout_006.csv
# ../batch_submission_W/Readout_008.csv
# ../batch_submission_W/Readout_010.csv
# ../batch_submission_W/Readout_012.csv
# ../batch_submission_W/Readout_014.csv
# ../batch_submission_W/Readout_016.csv
# ../batch_submission_W/Readout_018.csv
# ../batch_submission_W/Readout_020.csv
# ../batch_submission_W/Readout_022.csv
# ../batch_submission_W/Readout_024.csv
# ../batch_submission_W/Readout_026.csv
# ../batch_submission_W/Readout_028.csv
# ../batch_submission_W/Readout_030.csv
# ../batch_submission_W/Readout_032.csv
# ../batch_submission_W/Readout_034.csv
# ../batch_submission_W/Readout_036.csv
# ../batch_submission_W/Readout_038.csv
# ../batch_submission_W/Readout_040.csv
# ../batch_submission_W/Readout_042.csv
# ../batch_submission_W/Readout_044.csv
# ../batch_submission_W/Readout_046.csv
# ../batch_submission_W/Readout_048.csv
# ../batch_submission_W/Readout_050.csv
# ../batch_submission_W/Readout_052.csv
# ../batch_submission_W/Readout_054.csv
# ../batch_submission_W/Readout_056.csv
# ../batch_submission_W/Readout_058.csv
# ../batch_submission_W/Readout_060.csv
# ../batch_submission_W/Readout_062.csv
# ../batch_submission_W/Readout_064.csv
# ../batch_submission_W/Readout_066.csv
# ../batch_submission_W/Readout_068.csv
# ../batch_submission_W/Readout_070.csv
# ../batch_submission_W/Readout_072.csv
# ../batch_submission_W/Readout_074.csv
# ../batch_submission_W/Readout_076.csv
# ../batch_submission_W/Readout_078.csv
# ../batch_submission_W/Readout_080.csv
# ../batch_submission_W/Readout_082.csv
# ../batch_submission_W/Readout_084.csv
# ../batch_submission_W/Readout_086.csv
# ../batch_submission_W/Readout_088.csv
# ../batch_submission_W/Readout_090.csv
# ../batch_submission_W/Readout_092.csv
# ../batch_submission_W/Readout_094.csv
# ../batch_submission_W/Readout_096.csv
# ../batch_submission_W/Readout_098.csv
# ../batch_submission_W/Readout_100.csv
# ../batch_submission_W/Readout_102.csv
# ../batch_submission_W/Readout_104.csv
# ../batch_submission_W/Readout_106.csv
# ../batch_submission_W/Readout_108.csv
# ../batch_submission_W/Readout_110.csv
# ../batch_submission_W/Readout_112.csv
# ../batch_submission_W/Readout_114.csv
# ../batch_submission_W/Readout_116.csv
# ../batch_submission_W/Readout_118.csv
# ../batch_submission_W/Readout_120.csv
# ../batch_submission_W/Readout_122.csv
# ../batch_submission_W/Readout_124.csv
# ../batch_submission_W/Readout_126.csv
# ../batch_submission_W/Readout_128.csv
# ../batch_submission_W/Readout_130.csv
# ../batch_submission_W/Readout_132.csv
# ../batch_submission_W/Readout_134.csv
# ../batch_submission_W/Readout_136.csv
# ../batch_submission_W/Readout_138.csv
# ../batch_submission_W/Readout_140.csv
# ../batch_submission_W/Readout_142.csv
# ../batch_submission_W/Readout_144.csv
# ../batch_submission_W/Readout_146.csv
# ../batch_submission_W/Readout_148.csv
# ../batch_submission_W/Readout_150.csv
# ../batch_submission_W/Readout_152.csv
# ../batch_submission_W/Readout_154.csv
# ../batch_submission_W/Readout_156.csv
# ../batch_submission_W/Readout_158.csv
# ../batch_submission_W/Readout_160.csv
# ../batch_submission_W/Readout_162.csv
# ../batch_submission_W/Readout_164.csv
# ../batch_submission_W/Readout_166.csv
# ../batch_submission_W/Readout_168.csv
# ../batch_submission_W/Readout_170.csv
# ../batch_submission_W/Readout_172.csv
# ../batch_submission_W/Readout_174.csv
# ../batch_submission_W/Readout_176.csv
# ../batch_submission_W/Readout_178.csv
# ../batch_submission_W/Readout_180.csv
# ../batch_submission_W/Readout_182.csv
# ../batch_submission_W/Readout_184.csv
# ../batch_submission_W/Readout_186.csv
# ../batch_submission_W/Readout_188.csv
# ../batch_submission_W/Readout_190.csv
# ../batch_submission_W/Readout_192.csv
# ../batch_submission_W/Readout_194.csv
# ../batch_submission_W/Readout_196.csv
# ../batch_submission_W/Readout_198.csv
# ../batch_submission_W/Readout_200.csv
# ../batch_submission_W/Readout_202.csv
# ../batch_submission_W/Readout_204.csv
# ../batch_submission_W/Readout_206.csv
# ../batch_submission_W/Readout_208.csv
# ../batch_submission_W/Readout_210.csv
# ../batch_submission_W/Readout_212.csv
# ../batch_submission_W/Readout_214.csv
# ../batch_submission_W/Readout_216.csv
# ../batch_submission_W/Readout_218.csv
# ../batch_submission_W/Readout_220.csv
# ../batch_submission_W/Readout_222.csv
# ../batch_submission_W/Readout_224.csv
# ../batch_submission_W/Readout_226.csv
# ../batch_submission_W/Readout_228.csv
# ../batch_submission_W/Readout_230.csv
# ../batch_submission_W/Readout_232.csv
# ../batch_submission_W/Readout_234.csv
# ../batch_submission_W/Readout_236.csv
# ../batch_submission_W/Readout_238.csv
# ../batch_submission_W/Readout_240.csv
# ../batch_submission_W/Readout_242.csv
# ../batch_submission_W/Readout_244.csv
# ../batch_submission_W/Readout_246.csv
# ../batch_submission_W/Readout_248.csv
# ../batch_submission_W/Readout_250.csv
# ../batch_submission_W/Readout_252.csv
# ../batch_submission_W/Readout_254.csv
# ../batch_submission_W/Readout_256.csv
# ../batch_submission_W/Readout_258.csv
# ../batch_submission_W/Readout_260.csv
# ../batch_submission_W/Readout_262.csv
# ../batch_submission_W/Readout_264.csv
# ../batch_submission_W/Readout_266.csv
# ../batch_submission_W/Readout_268.csv
# ../batch_submission_W/Readout_270.csv
# ../batch_submission_W/Readout_272.csv
# ../batch_submission_W/Readout_274.csv
# ../batch_submission_W/Readout_276.csv
# ../batch_submission_W/Readout_278.csv
# ../batch_submission_W/Readout_280.csv
# ../batch_submission_W/Readout_282.csv
# ../batch_submission_W/Readout_284.csv
# ../batch_submission_W/Readout_286.csv
# ../batch_submission_W/Readout_288.csv
# ../batch_submission_W/Readout_290.csv
# ../batch_submission_W/Readout_292.csv
# ../batch_submission_W/Readout_294.csv
# ../batch_submission_W/Readout_296.csv
# ../batch_submission_W/Readout_298.csv
# ../batch_submission_W/Readout_300.csv
# ../batch_submission_W/Readout_302.csv
# ../batch_submission_W/Readout_304.csv
# ../batch_submission_W/Readout_306.csv
# ../batch_submission_W/Readout_308.csv
# ../batch_submission_W/Readout_310.csv
# ../batch_submission_W/Readout_312.csv
# ../batch_submission_W/Readout_314.csv
# ../batch_submission_W/Readout_316.csv
# ../batch_submission_W/Readout_318.csv
# ../batch_submission_W/Readout_320.csv
# ../batch_submission_W/Readout_322.csv
# ../batch_submission_W/Readout_324.csv
# ../batch_submission_W/Readout_326.csv
# ../batch_submission_W/Readout_328.csv
# ../batch_submission_W/Readout_330.csv
# ../batch_submission_W/Readout_332.csv
# ../batch_submission_W/Readout_334.csv
# ../batch_submission_W/Readout_336.csv
# ../batch_submission_W/Readout_338.csv
# ../batch_submission_W/Readout_340.csv
# ../batch_submission_W/Readout_342.csv
# ../batch_submission_W/Readout_344.csv
# ../batch_submission_W/Readout_346.csv
# ../batch_submission_W/Readout_348.csv
# ../batch_submission_W/Readout_350.csv
# ../batch_submission_W/Readout_352.csv
# ../batch_submission_W/Readout_354.csv
# ../batch_submission_W/Readout_356.csv
# ../batch_submission_W/Readout_358.csv

# %%
angles = np.linspace(0,360,180,endpoint=False)*np.pi/180

# %%
images[np.isinf(images)] = 0

# %%
#np.save('simulated_projs_W',images)
images = np.load('simulated_projs.npy')

# %%
geomet = tigre.geometry_default(high_quality=True,nVoxel = [64,512,512])
geomet.nDetector = np.array([128,512])
geomet.dDetector = np.array([0.784, 0.784])

# I think I can get away with this
geomet.sDetector = geomet.dDetector * geomet.nDetector    

geomet.sVoxel = np.array((160, 160, 160)) 
geomet.dVoxel = geomet.sVoxel/geomet.nVoxel

# %%
phantom = np.load('/home/xcite/xpecgen/xpecgen/data/phantoms/catphan_low_contrast_512.npy')

phantom2 = phantom.copy().astype(np.float32)

# %%
# projs = tigre.Ax(phantom2,geomet,angles)

# %%
# im = tigre.algorithms.FDK(projs,geomet,angles)

# %%
im4 = tigre.algorithms.FDK(images,geomet,angles)

# %%
im2 = tigre.algorithms.FDK(200*np.tile(np.mean(np.flip(images[:,:,:],0),1),[128,1,1]).transpose([1,0,2]),geomet,angles)

# %%
class IndexTracker(object):
    def __init__(self, ax, X):
        self.ax = ax
        ax.set_title('Geometry Viewer')

        self.X = X
        rows, cols, self.slices = X.shape
        self.ind = self.slices//2

        self.im = ax.imshow(self.X[:, :, self.ind])
        self.update()

    def onscroll(self, event):
        #print("%s %s" % (event.button, event.step))
        if event.button == 'up':
            self.ind = (self.ind + 1) % self.slices
        else:
            self.ind = (self.ind - 1) % self.slices
        self.update()

    def update(self):
        self.im.set_data(self.X[:, :, self.ind])
        self.ax.set_ylabel('slice %s' % self.ind)
        self.im.axes.figure.canvas.draw()

# %%
import pywt
from numpy.fft import fftshift, ifftshift, fft, ifft

def remove_stripe(img, level, wname='db5', sigma=1.5):
    """
    Suppress horizontal stripe in a sinogram using the Fourier-Wavelet based
    method by Munch et al. [2]_.

    Parameters
    ----------
    img : 2d array
        The two-dimensional array representig the image or the sinogram to de-stripe.

    level : int
        The highest decomposition level.

    wname : str, optional
        The wavelet type. Default value is ``db5``

    sigma : float, optional
        The damping factor in the Fourier space. Default value is ``1.5``

    Returns
    -------
    out : 2d array
        The resulting filtered image.

    References
    ----------
    .. [2] B. Munch, P. Trtik, F. Marone, M. Stampanoni, Stripe and ring artifact removal with
           combined wavelet-Fourier filtering, Optics Express 17(10):8567-8591, 2009.
    """

    nrow, ncol = img.shape

    # wavelet decomposition.
    cH = []; cV = []; cD = []

    for i in range(0, level):
        img, (cHi, cVi, cDi) = pywt.dwt2(img, wname)
        cH.append(cHi)
        cV.append(cVi)
        cD.append(cDi)

    # FFT transform of horizontal frequency bands
    for i in range(0, level):
        # FFT
        fcV=fftshift(fft(cV[i], axis=0))
        my, mx = fcV.shape

        # damping of vertical stripe information
        yy2  = (np.arange(-np.floor(my/2), -np.floor(my/2) + my))**2
        damp = - np.expm1( - yy2 / (2.0*(sigma**2)) )
        fcV  = fcV * np.tile(damp.reshape(damp.size, 1), (1,mx))

        #inverse FFT
        cV[i] = np.real( ifft( ifftshift(fcV), axis=0) )

    # wavelet reconstruction
    for i in  range(level-1, -1, -1):
        img = img[0:cH[i].shape[0], 0:cH[i].shape[1]]
        img = pywt.idwt2((img, (cH[i], cV[i], cD[i])), wname)

    return img[0:nrow, 0:ncol]

# %%
fig, ax = plt.subplots(1, 1)

tracker = IndexTracker(ax, im2.T)

fig.canvas.mpl_connect('scroll_event', tracker.onscroll)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
images2 = 200*np.tile(np.mean(np.flip(images[:,:,:],0),1),[128,1,1]).transpose([1,0,2])

# %%
plt.figure()
plt.imshow(images2[:,1,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# keep it in low

for ii in range(images2.shape[1]):
    
    images2[:,ii,:] = remove_stripe(images2[:,ii,:],1,wname='db30')

# %%
plt.figure()
plt.imshow(images2[:,1,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# im3 = tigre.algorithms.ossart(images2.astype(float32),geomet,angles,niter=50)
im3 = tigre.algorithms.FDK(images2.astype(float32),geomet,angles,filter="hamming")

# %%
fig, ax = plt.subplots(1, 1)

tracker = IndexTracker(ax, im3.T)

fig.canvas.mpl_connect('scroll_event', tracker.onscroll)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.save('FDK_topas_simulation_noise_reduced_W',im3.T)

# %%
fig = plt.figure(figsize=[9,9])

ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

tracker1 = IndexTracker(ax1, 10*rot90(np.tile(np.mean(images[:,:,:],1),[128,1,1]).transpose([1,0,2]).T))#transpose([0,2,1]))
tracker2 = IndexTracker(ax2, rot90(projs.T))


fig.canvas.mpl_connect('scroll_event', tracker2.onscroll)
fig.canvas.mpl_connect('scroll_event', tracker1.onscroll)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure()
plt.imshow(flood_128 - topas2numpy.BinnedResult(file).data['Sum'].squeeze().T)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
